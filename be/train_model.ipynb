# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
start_date = '2012-01-01'
end_date = '2021-01-01'
prediction_days = 60
scaler = MinMaxScaler(feature_range=(0, 1))

list_company = [
    'MMM', 'AXP', 'AAPL', 'BA', 'CAT',
    'CVX', 'CSCO', 'KO', 'DIS', 'DD',
    'XOM', 'GE', 'GS', 'HD', 'IBM',
    'INTC', 'JNJ', 'JPM', 'MCD', 'MRK',
    'MSFT', 'NKE', 'PFE', 'PG', 'TRV',
    'RTX', 'UNH', 'VZ', 'V', 'WMT'
]

# %%
# prepare data
x_train, y_train = [], []

for company in list_company:
  data  = pd.read_csv(f"train_data/{company.lower()}.csv")
  scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1, 1))
  for x in range (prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days : x, 0])
    y_train.append(scaled_data[x, 0])

x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

print(len(x_train), len(y_train))
# Out:
# 66150 66150

# %%
# build the model
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1)) # prediction of the next closing value

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=25, batch_size=32)
model.save("model.h5")
# Out:
# Epoch 1/25
# 2068/2068 [==============================] - 236s 111ms/step - loss: 0.0030
# Epoch 2/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 0.0013
# Epoch 3/25
# 2068/2068 [==============================] - 227s 110ms/step - loss: 9.2225e-04
# Epoch 4/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 8.3689e-04
# Epoch 5/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 7.9548e-04
# Epoch 6/25
# 2068/2068 [==============================] - 229s 111ms/step - loss: 7.7459e-04
# Epoch 7/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 7.4394e-04
# Epoch 8/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 7.3886e-04
# Epoch 9/25
# 2068/2068 [==============================] - 225s 109ms/step - loss: 7.2575e-04
# Epoch 10/25
# 2068/2068 [==============================] - 227s 110ms/step - loss: 7.3193e-04
# Epoch 11/25
# 2068/2068 [==============================] - 228s 110ms/step - loss: 7.0533e-04
# Epoch 12/25
# 2068/2068 [==============================] - 229s 111ms/step - loss: 7.0692e-04
# Epoch 13/25
# 2068/2068 [==============================] - 228s 110ms/step - loss: 6.8488e-04
# Epoch 14/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 6.8372e-04
# Epoch 15/25
# 2068/2068 [==============================] - 229s 111ms/step - loss: 6.7427e-04
# Epoch 16/25
# 2068/2068 [==============================] - 228s 110ms/step - loss: 6.7785e-04
# Epoch 17/25
# 2068/2068 [==============================] - 229s 111ms/step - loss: 6.6130e-04
# Epoch 18/25
# 2068/2068 [==============================] - 230s 111ms/step - loss: 6.5691e-04
# Epoch 19/25
# 2068/2068 [==============================] - 226s 109ms/step - loss: 6.6284e-04
# Epoch 20/25
# 2068/2068 [==============================] - 227s 110ms/step - loss: 6.6211e-04
# Epoch 21/25
# 2068/2068 [==============================] - 228s 110ms/step - loss: 6.4445e-04
# Epoch 22/25
# 2068/2068 [==============================] - 226s 110ms/step - loss: 6.6845e-04
# Epoch 23/25
# 2068/2068 [==============================] - 229s 111ms/step - loss: 6.4502e-04
# Epoch 24/25
# 2068/2068 [==============================] - 225s 109ms/step - loss: 6.3889e-04
# Epoch 25/25
# 2068/2068 [==============================] - 228s 110ms/step - loss: 6.4841e-04
